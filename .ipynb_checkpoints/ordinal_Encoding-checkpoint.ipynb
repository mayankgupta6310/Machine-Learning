# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("customer_data.csv")
df.sample(5)
# Out:
#       CustomerID  Age  Gender  AnnualIncome  SpendingScore LastPurchaseDate  \
# 5676        5677   42   Other     149201.74             29       2023-12-14
# 5934        5935   53    Male      24209.04             52       2021-05-04
# 1679        1680   22  Female      57316.63              2       2022-03-06
# 8464        8465   31    Male      96903.60             13       2022-12-25
# 3867        3868   56  Female     121057.60             38       2021-07-08
#
#      PurchaseCategory
# 5676          Grocery
# 5934      Electronics
# 1679         Clothing
# 8464         Clothing
# 3867          Grocery

# %%
df = df.iloc[:,2:]
df.head()
# Out:
#    Gender  AnnualIncome  SpendingScore LastPurchaseDate PurchaseCategory
# 0   Other     135670.31             41       2021-03-17        Furniture
# 1    Male      95108.48             93       2022-06-06           Sports
# 2  Female      78276.46             70       2022-06-05      Electronics
# 3  Female      74867.45             85       2022-11-29          Grocery
# 4   Other     136194.42             75       2021-06-30        Furniture

# %%
from sklearn .model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df["PurchaseCategory"],df["Gender"],test_size=0.2)

# %%
X_train
# Out:
# 3589    Electronics
# 149        Clothing
# 4474        Grocery
# 1837    Electronics
# 9850       Clothing
#            ...
# 5050         Sports
# 1688      Furniture
# 1041       Clothing
# 8465      Furniture
# 3977      Furniture
# Name: PurchaseCategory, Length: 8000, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories = [["Electronics","Clothing","Grocery","Furniture","Sports"]])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 oe.fit(X_train)
#
# File ~\Downloads\python.Mayank\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\Downloads\python.Mayank\Lib\site-packages\sklearn\preprocessing\_encoders.py:1516, in OrdinalEncoder.fit(self, X, y)
#    1509     raise TypeError(
#    1510         "unknown_value should only be set when "
#    1511         "handle_unknown is 'use_encoded_value', "
#    1512         f"got {self.unknown_value}."
#    1513     )
# ...
