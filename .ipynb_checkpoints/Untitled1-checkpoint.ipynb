# %%
import pandas as pd
import numpy as np

# %%
date = pd.read_csv("")

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
x = df.iloc[:,1:3]
y = df.iloc[:,0]

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state= 42)

# %%
plt.figure(figsize =(14,4))
plt.subplot(121)

# sns.distplot(X_train["Fare"], dist= "norm", plot= plt)
sns.histplot(X_train["Fare"], kde=True)
stats.probplot(X_train["Fare"], dist="norm", plot=plt)



plt.title("Age QQ plot")
plt.show()
