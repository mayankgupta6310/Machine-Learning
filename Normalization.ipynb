# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Wine dataset.csv",header = None, usecols= [0,1,2])
df.columns = ["class","Alcohal","Malic acid"]
df
# Out:
#      class  Alcohal  Malic acid
# 0    class  Alcohol  Malic acid
# 1        1    14.23        1.71
# 2        1     13.2        1.78
# 3        1    13.16        2.36
# 4        1    14.37        1.95
# ..     ...      ...         ...
# 174      3    13.71        5.65
# 175      3     13.4        3.91
# 176      3    13.27        4.28
# 177      3    13.17        2.59
# 178      3    14.13         4.1
#
# [179 rows x 3 columns]

# %%
df["Alcohal"].dtype

# df["Alcohal"].head()
# Out:
# dtype('O')

# %%
sns.kdeplot(df["Alcohal"].dropna(), fill=True, color="blue")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.kdeplot(df["Alcohal"].dropna(), fill=True, color="blue")
#
# File ~\Downloads\python.Mayank\Lib\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File ~\Downloads\python.Mayank\Lib\site-packages\seaborn\_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
# ...

# %%
color_dict = {1:"red",3:"green",2:"blue"}
# sns.scatterplot(df["Alcohal"].dropna(),  df["Malic acid"], hue= df["class"],palette = color_dict)
sns.scatterplot(x= "Alcohal", y= "Malic acid",data= df, hue= "class",palette = color_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 color_dict = {1:"red",3:"green",2:"blue"}
#       2 # sns.scatterplot(df["Alcohal"].dropna(),  df["Malic acid"], hue= df["class"],palette = color_dict)
# ----> 3 sns.scatterplot(x= "Alcohal", y= "Malic acid",data= df, hue= "class",palette = color_dict)
#
# File ~\Downloads\python.Mayank\Lib\site-packages\seaborn\relational.py:621, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
#     615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
# ...
