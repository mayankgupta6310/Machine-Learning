# %%
import pandas as pd

# %%
df = pd.read_csv("aug_train.csv")

# %%
df.shape
# Out:
# (19158, 14)

# %%
df.sample(5)   # random rows are print
# Out:
#        enrollee_id      city  city_development_index gender  \
# 2170          3538  city_103                   0.920   Male
# 4458         18608   city_21                   0.624   Male
# 14826        12356  city_143                   0.740   Male
# 4212          1686  city_103                   0.920   Male
# 1381         28081  city_160                   0.920   Male
#
#            relevent_experience enrolled_university education_level  \
# 2170   Has relevent experience       no_enrollment        Graduate
# 4458   Has relevent experience       no_enrollment        Graduate
# 14826  Has relevent experience       no_enrollment        Graduate
# 4212    No relevent experience    Full time course        Graduate
# 1381    No relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 2170        Humanities        >20       10000+      Pvt Ltd           >4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr()['relevent_experience']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.corr()['relevent_experience']
#
# File ~\Downloads\python.Mayank\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\Downloads\python.Mayank\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# !git --version
# Out:
# git version 2.51.0.windows.1

# %%
# !git clone https://github.com/mayankgupta6310/Machine-Learning.git
# Out:
# Cloning into 'Machine-Learning'...
